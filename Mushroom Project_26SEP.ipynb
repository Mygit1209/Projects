# %% [markdown]
# # Importing the Dataset

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("mushrooms.csv")

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %% [markdown]
# # Checking null values in the DataFrame

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %% [raw]
# There are no null values in this dataset.

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %% [markdown]
# # DataFrame Description

# %% [raw]
# In this dataset class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat' are the columns.
#
#     "class" is a target column.

# %% [markdown]
# # check the datatypes

# %%
df.dtypes
# Out:
# class                       object
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %%
df["class"].unique()
# Out:
# array(['p', 'e'], dtype=object)

# %%
df['class'].value_counts()
# Out:
# e    4208
# p    3916
# Name: class, dtype: int64

# %% [markdown]
# # Converting the column datatypes using LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

lencode=LabelEncoder()
df['class'] = lencode.fit_transform(df['class'])
df
# Out:
#       class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0         1         x           s         n       t    p               f
# 1         0         x           s         y       t    a               f
# 2         0         b           s         w       t    l               f
# 3         1         x           y         w       t    p               f
# 4         0         x           s         g       f    n               f
# ...     ...       ...         ...       ...     ...  ...             ...
# 8119      0         k           s         n       f    n               a
# 8120      0         x           s         n       f    n               a
# 8121      0         f           s         n       f    n               a
# 8122      1         k           y         n       f    y               f
# 8123      0         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
cols = [ 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
       'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
       'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
       'ring-type', 'spore-print-color', 'population', 'habitat']
#
# Encode labels of multiple columns at once
#
df[cols] = df[cols].apply(LabelEncoder().fit_transform)
#
# Print head
#
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %% [raw]
# now whole dataset converted into numerical format.

# %%
df["class"].unique()
# Out:
# array([1, 0])

# %%
df['class'].value_counts()
# Out:
# 0    4208
# 1    3916
# Name: class, dtype: int64

# %% [markdown]
# # Visualization of Data

# %%
import seaborn as sns

# %%
df_visualization_nominal=df[['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
       'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
       'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
       'ring-type', 'spore-print-color', 'population', 'habitat']].copy()

# %%
df_visualization_nominal.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
ax = sns.countplot(x="class", data=df_visualization_nominal)
print(df_visualization_nominal["class"].value_counts())
# Out:
# 0    4208
# 1    3916
# Name: class, dtype: int64

# %% [raw]
# From the above observations the total number of 0's 4208 and total number of 1's is 3916.

# %%
ax = sns.countplot(x="cap-shape", data=df_visualization_nominal)
print(df_visualization_nominal["cap-shape"].value_counts())
# Out:
# 5    3656
# 2    3152
# 3     828
# 0     452
# 4      32
# 1       4
# Name: cap-shape, dtype: int64

# %% [raw]
# from the above observation cap shape of 0 is having a 452 caps, 1 is having a 4 caps, 2 is having a 3152 caps ,3 is having a 828 caps ,4 is having a 32 caps, 5 is having a 3656 caps.

# %%
ax = sns.countplot(x="cap-surface", data=df_visualization_nominal)
print(df_visualization_nominal["cap-surface"].value_counts())
# Out:
# 3    3244
# 2    2556
# 0    2320
# 1       4
# Name: cap-surface, dtype: int64

# %% [raw]
# from the above observation cap surface 0 have 2320, 1 have 4, 2 have 2556, 3 have 3244.

# %%
ax = sns.countplot(x="cap-color", data=df_visualization_nominal)
print(df_visualization_nominal["cap-color"].value_counts())
# Out:
# 4    2284
# 3    1840
# 2    1500
# 9    1072
# 8    1040
# 0     168
# 5     144
# 1      44
# 7      16
# 6      16
# Name: cap-color, dtype: int64

# %%
ax = sns.countplot(x="bruises", data=df_visualization_nominal)
print(df_visualization_nominal["bruises"].value_counts())
# Out:
# 0    4748
# 1    3376
# Name: bruises, dtype: int64

# %%
ax = sns.countplot(x="odor", data=df_visualization_nominal)
print(df_visualization_nominal["odor"].value_counts())
# Out:
# 5    3528
# 2    2160
# 7     576
# 8     576
# 3     400
# 0     400
# 6     256
# 1     192
# 4      36
# Name: odor, dtype: int64

# %%
ax = sns.countplot(x="gill-attachment", data=df_visualization_nominal)
print(df_visualization_nominal["gill-attachment"].value_counts())
# Out:
# 1    7914
# 0     210
# Name: gill-attachment, dtype: int64

# %%
ax = sns.countplot(x="habitat", data=df_visualization_nominal)
print(df_visualization_nominal["habitat"].value_counts())
# Out:
# 0    3148
# 1    2148
# 4    1144
# 2     832
# 5     368
# 3     292
# 6     192
# Name: habitat, dtype: int64

# %%
ax = sns.countplot(x="population", data=df_visualization_nominal)
print(df_visualization_nominal["population"].value_counts())
# Out:
# 4    4040
# 5    1712
# 3    1248
# 2     400
# 0     384
# 1     340
# Name: population, dtype: int64

# %%
import seaborn as sns
df_visualization=df_visualization[["population","habitat"]].copy()

# %%
sns.distplot(df_visualization['population'], kde=True)
# Out:
# F:\Namrata\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='population', ylabel='Density'>

# %%
sns.distplot(df_visualization['habitat'], kde=True)
# Out:
# F:\Namrata\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='habitat', ylabel='Density'>

# %% [markdown]
# # Describe the Dataset

# %%
df.describe()
# Out:
#              class    cap-shape  cap-surface    cap-color      bruises  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      0.482029     3.348104     1.827671     4.504677     0.415559
# std       0.499708     1.604329     1.229873     2.545821     0.492848
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     3.000000     0.000000
# 50%       0.000000     3.000000     2.000000     4.000000     0.000000
# 75%       1.000000     5.000000     3.000000     8.000000     1.000000
# max       1.000000     5.000000     3.000000     9.000000     1.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  8124.000000      8124.000000   8124.000000  8124.000000  8124.000000
# mean      4.144756         0.974151      0.161497     0.309207     4.810684
# std       2.103729         0.158695      0.368011     0.462195     3.540359
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(22,7))
sns.heatmap(df.describe(),annot=True,linewidths=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000   0.052951     0.178446  -0.031384
# cap-shape                 0.052951   1.000000    -0.050454  -0.048203
# cap-surface               0.178446  -0.050454     1.000000  -0.019402
# cap-color                -0.031384  -0.048203    -0.019402   1.000000
# bruises                  -0.501530  -0.035374     0.070228  -0.000764
# odor                     -0.093552  -0.021935     0.045233  -0.387121
# gill-attachment           0.129200   0.078865    -0.034180   0.041436
# gill-spacing             -0.348387   0.013196    -0.282306   0.144259
# gill-size                 0.540024   0.054050     0.208100  -0.169464
# gill-color               -0.530566  -0.006039    -0.161017   0.084659
# stalk-shape              -0.102019   0.063794    -0.014123  -0.456496
# stalk-root               -0.379361   0.030191    -0.126245   0.321274
# ...

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.corr(),annot=True,linewidths=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,7))
df.corr()['class'].sort_values(ascending=False).drop(['class']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.skew()
# Out:
# class                       0.071946
# cap-shape                  -0.247052
# cap-surface                -0.590859
# cap-color                   0.706965
# bruises                     0.342750
# odor                       -0.080790
# gill-attachment            -5.977076
# gill-spacing                1.840088
# gill-size                   0.825797
# gill-color                  0.061410
# stalk-shape                -0.271345
# stalk-root                  0.947852
# stalk-surface-above-ring   -1.098739
# stalk-surface-below-ring   -0.757703
# stalk-color-above-ring     -1.835434
# stalk-color-below-ring     -1.791593
# veil-type                   0.000000
# veil-color                 -6.946944
# ring-number                 2.701657
# ring-type                  -0.290018
# spore-print-color           0.548426
# population                 -1.413096
# habitat                     0.985548
# dtype: float64

# %% [raw]
# Keeping +/-0.5 as the range for skewness, here are the columns which does not lie within this range.
# Since, no column has skewness, we will not treat that.

# %%
df.dtypes
# Out:
# class                       int32
# cap-shape                   int32
# cap-surface                 int32
# cap-color                   int32
# bruises                     int32
# odor                        int32
# gill-attachment             int32
# gill-spacing                int32
# gill-size                   int32
# gill-color                  int32
# stalk-shape                 int32
# stalk-root                  int32
# stalk-surface-above-ring    int32
# stalk-surface-below-ring    int32
# stalk-color-above-ring      int32
# stalk-color-below-ring      int32
# veil-type                   int32
# veil-color                  int32
# ring-number                 int32
# ring-type                   int32
# spore-print-color           int32
# population                  int32
# habitat                     int32
# dtype: object

# %% [raw]
# Checking the outliers on the int and float type of columns.

# %%
df['habitat'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['population'].plot.box()
# Out:
# <AxesSubplot:>

# %% [raw]
# outlier is present

# %% [markdown]
# # scaling

# %%
df.keys()
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
x=df.drop("class",axis=1)
y=df["class"]

# %%
x
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0             5            2          4        1     6                1
# 1             5            2          9        1     0                1
# 2             0            2          8        1     3                1
# 3             5            3          8        1     6                1
# 4             5            2          3        0     5                1
# ...         ...          ...        ...      ...   ...              ...
# 8119          3            2          4        0     5                0
# 8120          5            2          4        0     5                0
# 8121          2            2          4        0     5                0
# 8122          3            3          4        0     8                1
# 8123          5            2          4        0     5                0
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# ...

# %%
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 8119    0
# 8120    0
# 8121    0
# 8122    1
# 8123    0
# Name: class, Length: 8124, dtype: int32

# %%
x.shape
# Out:
# (8124, 22)

# %%
y.shape
# Out:
# (8124,)

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import ccuracy_scoare


import warnings
warnings.filterwarnings('ignore')

# %%
mms=MinMaxScaler()
lr=LinearRegression()

# %%
x_train,y_train,x_test,y_test = train_test_split(x,y,test_size=0.30,random_state=42)

# %%
lr.fit(x_train,y_train)
pred = lr.predict(x_test)
print(r2_score(y_test,pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-b2debddb8a1b> in <module>
# ----> 1 lr.fit(x_train,y_train)
#       2 #pred = lr.predict(x_test)
#       3 #print(r2_score(y_test,pred))
#
# F:\Namrata\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     516         accept_sparse = False if self.positive else ['csr', 'csc', 'coo']
#     517
# --> 518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
#     519                                    y_numeric=True, multi_output=True)
#     520
#
# F:\Namrata\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
# ...

# %%
stuck here and not enough time to resolve it...please help me
