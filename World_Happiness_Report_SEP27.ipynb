# %% [markdown]
# # Importing Dataset

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("happiness_score_dataset.csv")
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
# Checking null values in the dataset

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [raw]
# There is no null values in this dataset.

# %%
df.shape
# Out:
# (158, 12)

# %% [markdown]
# There are 158 rows and 12 columns in this dataset.

# %%
df.dtypes

# %% [raw]
# we have float type value in all independant variables
# and Region is our target variable where in we have classes

# %%
df['Country'].unique()

# %%
df['Region'].unique()

# %% [raw]
# There are 10 unique values in df['Region']

# %%
df['Region'].value_counts()

# %% [markdown]
# # Visualization of Data

# %% [raw]
# For the nominal categorical data we will use countplot as it will give the frequency of the classes of the columns.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(df['Region'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %%
All 10 classes are not equally distributed. there is class imbalance isses exists.

# %%
sns.distplot(df['Dystopia Residual'])
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Density'>

# %% [raw]
# Data is normally distributed in this column. --->use mean

# %%
sns.distplot(df['Happiness Rank'])
# Out:
# <AxesSubplot:xlabel='Happiness Rank', ylabel='Density'>

# %% [raw]
# Data is normally distributed in this column. --->use mean

# %%
sns.distplot(df['Happiness Score'])
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Density'>

# %%
Data is normally distributed in this column. --->use mean

# %%
sns.boxplot(df['Happiness Rank'])
# Out:
# <AxesSubplot:xlabel='Happiness Rank'>

# %% [raw]
# There is no outliers in 'Happiness Rank'.

# %%
sns.boxplot(df['Dystopia Residual'])
# Out:
# <AxesSubplot:xlabel='Dystopia Residual'>

# %% [raw]
# outliers present in 'Dystopia Residual'.

# %%
sns.boxplot(df['Generosity'])
# Out:
# <AxesSubplot:xlabel='Generosity'>

# %% [raw]
# outliers present in 'Generosity'.

# %%
sns.boxplot(df['Happiness Score'])
# Out:
# <AxesSubplot:xlabel='Happiness Score'>

# %% [raw]
# There is no outlier present in 'Happiness Score'.

# %%
sns.boxplot(df['Trust (Government Corruption)'])
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)'>

# %% [raw]
# outliers present in 'Trust (Government Corruption)'.

# %% [markdown]
# # Bi Variate Analysis

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between Freedom and Trust (Government Corruption)')
sns.scatterplot(df['Freedom'], df['Trust (Government Corruption)']);

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between Freedom and Trust (Government Corruption)')
sns.scatterplot(df['Freedom'], df['Trust (Government Corruption)'], hue = df["Freedom"]);

# %%
sns.pairplot(df,hue='Freedom')

# %%
cor = df.corr()
cor
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
sns.heatmap(cor,annot=True,linewidths=1,linecolor='r')
# Out:
# <AxesSubplot:>

# %% [raw]
# In this heatmap ,
# 1. happiness rank will affect Health ,Family, Economy(GDP per capital), and Happiness scores negatively.
# 2. happiness score will affect Happiness Rank negatively.
# 3. Economy(GDP per capital) affect Happiness Rank ,it shows negative impact.
# 4. Family will affect Happiness Rank negatively.
# 5. Health(Life Expentancy) will affect Happiness Rank.
# 6. Freedom will affect Happiness Rank.
# 7. Trust(Government Corruption) will affect Happiness Rank.
# 8. Dystopia Residual will affect Happiness Rank

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %% [raw]
# Now here we have country and region column have string value..we have to convertit into integer. because machine understand only integer values using Label Encoder.

# %% [markdown]
# # Encode Data

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
df["Country"] = LE.fit_transform(df['Country'])

# %%
df['Country'].unique()
# Out:
# array([135,  58,  37, 105,  24,  45,  99, 134, 100,   6,  64,  33,   7,
#         91, 150,  18,  82,  63,  12, 148, 149, 106, 153, 123, 109,  49,
#         27, 115,  46,   4,  36, 151,  29, 140, 119, 129,  88, 137,  73,
#        132, 142,  42,  52, 152, 124,  68, 128,  40,   9,  65,  15,  92,
#        110,  70, 125,  81, 101, 111,  11, 113,  86,  34,  80, 117,  67,
#        104,  35,   2,  72, 145,  90,  56,  43,  60, 154, 144,  74, 103,
#         14,   8, 107,  69,  94,  28, 156, 116, 121, 114,  76, 112, 126,
#         95,  83,  96,   1,  16,  78,  39,  75,  93, 133,  51,  77,  57,
#         55, 138, 143, 108,  10,  61, 147,  62, 127,  50, 157,  79,  59,
#        131,  54,  32,  98,  44, 122,  89,  71,  38,   5,  17,  97,  48,
#         85, 130,  23,  19,  41, 155,   3,  87,  31,  30, 146, 120,  47,
#        102,  22, 139,  84,  25,  26,  53,  66,  20,   0, 118,  13, 136,
#         21, 141])

# %%
df.head()
# Out:
#    Country          Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135  Western Europe               1            7.587         0.03411
# 1       58  Western Europe               2            7.561         0.04884
# 2       37  Western Europe               3            7.527         0.03328
# 3      105  Western Europe               4            7.522         0.03880
# 4       24   North America               5            7.427         0.03553
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# ...

# %% [raw]
# Now Country will convert into integer datatype.

# %%
df["Region"] = LE.fit_transform(df['Region'])

# %%
df['Region'].unique()
# Out:
# array([9, 5, 0, 4, 3, 6, 1, 2, 8, 7])

# %%
df.head()
# Out:
#    Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135       9               1            7.587         0.03411
# 1       58       9               2            7.561         0.04884
# 2       37       9               3            7.527         0.03328
# 3      105       9               4            7.522         0.03880
# 4       24       5               5            7.427         0.03553
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# ...

# %%
Now Region will convert into integer datatyape.

# %% [markdown]
# # Outlier Removal

# %%
from scipy.stats import zscore

z = np.abs(zscore(df))

df1 = df[(z<3).all(axis=1)]

# %%
df1.shape
# Out:
# (149, 12)

# %%
df.shape
# Out:
# (158, 12)

# %%
1/158
# Out:
# 0.006329113924050633

# %% [raw]
# so skewness is less than 0.5 so no need to control it.

# %% [markdown]
# # Skewness

# %%
df1.skew()
# Out:
# Country                          0.048701
# Region                          -0.096985
# Happiness Rank                   0.003268
# Happiness Score                  0.169740
# Standard Error                   1.243048
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %%
x = df1.drop("Region",axis=1)
y = df1['Region']

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier

# %%
for i in range(200):
    x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=i)
    from sklearn.tree import DecisionTreeClassifier
    lm = DecisionTreeClassifier()
    lm.fit(x_train,y_train)
    pred=lm.predict(x_test)
    accu=accuracy_score(y_test,pred)
    print(accu*100,'at random state',i)
# Out:
# 60.0 at random state 0
# 57.99999999999999 at random state 1
# 60.0 at random state 2
# 66.0 at random state 3
# 50.0 at random state 4
# 50.0 at random state 5
# 42.0 at random state 6
# 48.0 at random state 7
# 57.99999999999999 at random state 8
# 46.0 at random state 9
# 46.0 at random state 10
# 62.0 at random state 11
# 50.0 at random state 12
# 62.0 at random state 13
# 74.0 at random state 14
# 64.0 at random state 15
# 56.00000000000001 at random state 16
# 57.99999999999999 at random state 17
# 54.0 at random state 18
# 60.0 at random state 19
# 64.0 at random state 20
# 64.0 at random state 21
# 57.99999999999999 at random state 22
# 64.0 at random state 23
# 60.0 at random state 24
# 57.99999999999999 at random state 25
# 60.0 at random state 26
# 48.0 at random state 27
# 52.0 at random state 28
# 54.0 at random state 29
# 50.0 at random state 30
# 50.0 at random state 31
# 50.0 at random state 32
# 68.0 at random state 33
# 54.0 at random state 34
# ...

# %%
# find the best accuracy score

from sklearn.tree import DecisionTreeClassifier
MaxAccu=0
MaxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.30,random_state=i)
    mod = DecisionTreeClassifier()
    mod.fit(x_train,y_train)
    pred = mod.predict(x_test)
    acc = accuracy_score(y_test,pred)
    if acc>MaxAccu:
        MaxAccu=acc
        MaxRS=i
    print("Best Accuracy is", MaxAccu,"on Random_state",MaxRS)
# Out:
# Best Accuracy is 0.6888888888888889 on Random_state 1
# Best Accuracy is 0.6888888888888889 on Random_state 1
# Best Accuracy is 0.6888888888888889 on Random_state 1
# Best Accuracy is 0.6888888888888889 on Random_state 1
# Best Accuracy is 0.6888888888888889 on Random_state 1
# Best Accuracy is 0.6888888888888889 on Random_state 1
# Best Accuracy is 0.6888888888888889 on Random_state 1
# Best Accuracy is 0.6888888888888889 on Random_state 1
# Best Accuracy is 0.6888888888888889 on Random_state 1
# Best Accuracy is 0.6888888888888889 on Random_state 1
# Best Accuracy is 0.6888888888888889 on Random_state 1
# Best Accuracy is 0.6888888888888889 on Random_state 1
# Best Accuracy is 0.6888888888888889 on Random_state 1
# Best Accuracy is 0.7111111111111111 on Random_state 14
# Best Accuracy is 0.7111111111111111 on Random_state 14
# Best Accuracy is 0.7111111111111111 on Random_state 14
# Best Accuracy is 0.7111111111111111 on Random_state 14
# ...

# %%
x_train, y_train, x_test, y_test = train_test_split(x,y,test_size=.30,random_state=12)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report

# %%
DTC = DecisionTreeClassifier()
DTC.fit(x_train,y_train)
pred = DTC.predict(x_test)
acc = classification_report(y_test,pred)
print(acc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-8ea2f118b451> in <module>
#       1 DTC = DecisionTreeClassifier()
# ----> 2 DTC.fit(x_train,y_train)
#       3 pred = DTC.predict(x_test)
#       4 acc = classification_report(y_test,pred)
#       5 print(acc)
#
# F:\Namrata\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     901         """
#     902
# --> 903         super().fit(
#     904             X, y,
#     905             sample_weight=sample_weight,
#
# F:\Namrata\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     189
#     190         if is_classification:
# --> 191             check_classification_targets(y)
#     192             y = np.copy(y)
#     193
#
# ...
