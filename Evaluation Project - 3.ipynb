# %% [markdown]
# # Avacado Project

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("avocado.csv")
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0         0.0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1         1.0  20-12-2015          1.35      54876.98   674.28   44638.81
# 2         2.0  13-12-2015          0.93     118220.22   794.70  109149.67
# 3         3.0  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4         4.0  29-11-2015          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#      year  region
# 0  2015.0  Albany
# 1  2015.0  Albany
# 2  2015.0  Albany
# ...

# %% [raw]
# The dataset can be seen in two angles classification as well as regression. and target column is AveragePrice.

# %% [markdown]
# # Describing Dataset

# %%
df.shape
# Out:
# (16468, 14)

# %% [raw]
# Here we have 16468 rows and 14 columns in this dataset.

# %%
df.dtypes
# Out:
# Unnamed: 0      float64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year            float64
# region           object
# dtype: object

# %% [raw]
# mostly all the independant variables are have a float datatype ..only few columns(Date,type and region) have object datatype. we have to convert it into integer .

# %% [raw]
# # we have to convert column type and region into 0 1 format.

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder

# %%
lencode=LabelEncoder()
df['type'] = lencode.fit_transform(df['type'])
df['region'] = lencode.fit_transform(df['region'])
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0             0.0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1             1.0  20-12-2015          1.35      54876.98   674.28   44638.81
# 2             2.0  13-12-2015          0.93     118220.22   794.70  109149.67
# 3             3.0  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4             4.0  29-11-2015          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 16463         NaN         NaN           NaN           NaN      NaN        NaN
# 16464         NaN         NaN           NaN           NaN      NaN        NaN
# 16465         NaN         NaN           NaN           NaN      NaN        NaN
# 16466         NaN         NaN           NaN           NaN      NaN        NaN
# 16467         NaN         NaN           NaN           NaN      NaN        NaN
#
# ...

# %% [raw]
# now our data are converted into integer format so now Adding new columns day, month and year in dataframe with date attribute.

# %%
import pandas as pd
import datetime

dt=datetime.datetime.now()
print(dt)

print(dt+pd.to_timedelta(10,unit='D'))
# Out:
# 2021-10-27 23:00:15.608672
# 2021-11-06 23:00:15.608672

# %%
df['Date'] =pd.to_datetime(df['Date'])

df['Date']

df['Day']=df['Date'].dt.day
df['Month']=df['Date'].dt.month
df['Year']=df['Date'].dt.year
df.head()
# Out:
#    Unnamed: 0       Date  AveragePrice  Total Volume     4046       4225  \
# 0         0.0 2015-12-27          1.33      64236.62  1036.74   54454.85
# 1         1.0 2015-12-20          1.35      54876.98   674.28   44638.81
# 2         2.0 2015-12-13          0.93     118220.22   794.70  109149.67
# 3         3.0 2015-06-12          1.08      78992.15  1132.00   71976.41
# 4         4.0 2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags  type    year  \
# 0   48.16     8696.87     8603.62       93.25          0.0     0  2015.0
# 1   58.33     9505.56     9408.07       97.49          0.0     0  2015.0
# 2  130.50     8145.35     8042.21      103.14          0.0     0  2015.0
# 3   72.58     5811.16     5677.40      133.76          0.0     0  2015.0
# 4   75.78     6183.95     5986.26      197.69          0.0     0  2015.0
#
#    region   Day  Month    Year
# 0       0  27.0   12.0  2015.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16468 entries, 0 to 16467
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1517 non-null   float64
#  1   Date          1517 non-null   datetime64[ns]
#  2   AveragePrice  1517 non-null   float64
#  3   Total Volume  1517 non-null   float64
#  4   4046          1517 non-null   float64
#  5   4225          1517 non-null   float64
#  6   4770          1517 non-null   float64
#  7   Total Bags    1517 non-null   float64
#  8   Small Bags    1517 non-null   float64
#  9   Large Bags    1517 non-null   float64
#  10  XLarge Bags   1517 non-null   float64
#  11  type          16468 non-null  int32
#  12  year          1517 non-null   float64
#  13  region        16468 non-null  int32
#  14  Day           1517 non-null   float64
#  15  Month         1517 non-null   float64
#  16  Year          1517 non-null   float64
# ...

# %% [raw]
# this will show the columns datatype and memory usage.

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      14951
# Date            14951
# AveragePrice    14951
# Total Volume    14951
# 4046            14951
# 4225            14951
# 4770            14951
# Total Bags      14951
# Small Bags      14951
# Large Bags      14951
# XLarge Bags     14951
# type                0
# year            14951
# region              0
# Day             14951
# Month           14951
# Year            14951
# dtype: int64

# %% [raw]
# there are lots of null data in this dataset..we have to handle it.

# %% [markdown]
# # Replace null values with NaN

# %%
#df['Unnamed'].replace('',np.nan,inplace=True)
df['Date'].replace('',np.nan,inplace=True)
df['AveragePrice'].replace('',np.nan,inplace=True)
df['Total Volume'].replace('',np.nan,inplace=True)
df['4046'].replace('',np.nan,inplace=True)
df['4225'].replace('',np.nan,inplace=True)
df['4770'].replace('',np.nan,inplace=True)
df['Total Bags'].replace('',np.nan,inplace=True)
df['Small Bags'].replace('',np.nan,inplace=True)
df['Large Bags'].replace('',np.nan,inplace=True)
df['XLarge Bags'].replace('',np.nan,inplace=True)
df['Day'].replace('',np.nan,inplace=True)
df['Month'].replace('',np.nan,inplace=True)
df['Year'].replace('',np.nan,inplace=True)

# %%
df
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume     4046       4225  \
# 0             0.0 2015-12-27          1.33      64236.62  1036.74   54454.85
# 1             1.0 2015-12-20          1.35      54876.98   674.28   44638.81
# 2             2.0 2015-12-13          0.93     118220.22   794.70  109149.67
# 3             3.0 2015-06-12          1.08      78992.15  1132.00   71976.41
# 4             4.0 2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...        ...           ...           ...      ...        ...
# 16463         NaN        NaT           NaN           NaN      NaN        NaN
# 16464         NaN        NaT           NaN           NaN      NaN        NaN
# 16465         NaN        NaT           NaN           NaN      NaN        NaN
# 16466         NaN        NaT           NaN           NaN      NaN        NaN
# 16467         NaN        NaT           NaN           NaN      NaN        NaN
#
# ...

# %% [raw]
# we replace all the null values with NaN..now using dropna fumction we drop the NaN values.

# %% [markdown]
# # Using Dropna function

# %%
df.dropna(subset=['Date'], inplace=True)
df.dropna(subset=['AveragePrice'], inplace=True)
df.dropna(subset=['Total Volume'], inplace=True)
df.dropna(subset=['4046'], inplace=True)
df.dropna(subset=['4225'], inplace=True)
df.dropna(subset=['4770'], inplace=True)
df.dropna(subset=['Total Bags'], inplace=True)
df.dropna(subset=['Small Bags'], inplace=True)
df.dropna(subset=['Large Bags'], inplace=True)
df.dropna(subset=['XLarge Bags'], inplace=True)
df.dropna(subset=['Day'], inplace=True)
df.dropna(subset=['Month'], inplace=True)
df.dropna(subset=['Year'], inplace=True)

print(df)
# Out:
#       Unnamed: 0       Date  AveragePrice  Total Volume      4046       4225  \
# 0            0.0 2015-12-27          1.33      64236.62   1036.74   54454.85
# 1            1.0 2015-12-20          1.35      54876.98    674.28   44638.81
# 2            2.0 2015-12-13          0.93     118220.22    794.70  109149.67
# 3            3.0 2015-06-12          1.08      78992.15   1132.00   71976.41
# 4            4.0 2015-11-29          1.28      51039.60    941.48   43838.39
# ...          ...        ...           ...           ...       ...        ...
# 1512        10.0 2016-10-16          1.39     190846.01  57529.11   56366.66
# 1513        11.0 2016-09-10          1.51     178235.75  43325.87   52189.61
# 1514        12.0 2016-02-10          1.48     178410.82  46364.75   52893.38
# 1515        13.0 2016-09-25          1.47     189131.52  54110.79   53593.58
# 1516        14.0 2016-09-18          1.43     182978.30  43116.41   54193.42
#
# ...

# %% [raw]
# Now we drop all the null values..lets check with help of df.isnull().sum()

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# Day             0
# Month           0
# Year            0
# dtype: int64

# %%
df.shape
# Out:
# (1517, 17)

# %% [raw]
#  now we have 1517 rows and 17 columns.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
sns.countplot(df['region']);

# %%
sns.violinplot(x = "Total Volume",data=df)

plt.show()

# %%
sns.distplot(df['AveragePrice'])
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Density'>

# %%
sns.distplot(df['Total Volume'])
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='Density'>

# %%
sns.distplot(df['4046'])
# Out:
# <AxesSubplot:xlabel='4046', ylabel='Density'>

# %%
sns.distplot(df['4225'])
# Out:
# <AxesSubplot:xlabel='4225', ylabel='Density'>

# %%
sns.distplot(df['4770'])
# Out:
# <AxesSubplot:xlabel='4770', ylabel='Density'>

# %%
sns.distplot(df['Total Bags'])
# Out:
# <AxesSubplot:xlabel='Total Bags', ylabel='Density'>

# %%
sns.boxplot(df['Small Bags'])
# Out:
# <AxesSubplot:xlabel='Small Bags'>

# %%
sns.boxplot(df['Large Bags'])
# Out:
# <AxesSubplot:xlabel='Large Bags'>

# %%
sns.boxplot(df['XLarge Bags'])
# Out:
# <AxesSubplot:xlabel='XLarge Bags'>

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between Small bags and large bags')
sns.scatterplot(df['Small Bags'], df['Large Bags']);

# %%
sns.pairplot(df,hue='region')

# %% [raw]
# Few outliers are present in this dataset..we have to handle it.

# %%
df.describe()
# Out:
#         Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  1517.000000   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03
# mean     26.995386      1.074990  1.601879e+06  6.464387e+05  6.114375e+05
# std      14.848287      0.188891  4.433143e+06  1.947614e+06  1.672906e+06
# min       0.000000      0.490000  3.875074e+04  4.677200e+02  1.783770e+03
# 25%      14.000000      0.980000  1.474700e+05  2.040034e+04  4.147606e+04
# 50%      29.000000      1.080000  4.027919e+05  8.175117e+04  1.186649e+05
# 75%      39.000000      1.190000  9.819751e+05  3.775785e+05  4.851503e+05
# max      51.000000      1.680000  4.465546e+07  1.893304e+07  1.895648e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000
# mean   5.040550e+04  2.935974e+05  2.487736e+05  4.264205e+04    2181.771074
# ...

# %% [raw]
# Observations:
#
# not much high gap between 75th percentile and max is present in AveragePrice. so few outliers is present.

# %%
df.skew()
# Out:
# Unnamed: 0     -0.234824
# AveragePrice   -0.109444
# Total Volume    6.200138
# 4046            6.051830
# 4225            6.394926
# 4770            5.405164
# Total Bags      5.366378
# Small Bags      5.355185
# Large Bags      5.144495
# XLarge Bags     5.775077
# type            0.000000
# year            1.828332
# region          0.288146
# Day             0.041303
# Month           0.101439
# Year            1.828332
# dtype: float64

# %% [raw]
# The range of skewness is +- 0.65 In many columns skewness are present so we have to control it.

# %%
df['Total Volume'] = np.sqrt(df['Total Volume'])
df['4046'] = np.sqrt(df['4046'])
df['4225'] = np.sqrt(df['4225'])
df['4770'] = np.sqrt(df['4770'])
df['Total Bags'] = np.sqrt(df['Total Bags'])
df['Small Bags'] = np.sqrt(df['Small Bags'])
df['Large Bags'] = np.sqrt(df['Large Bags'])
df['XLarge Bags'] = np.sqrt(df['XLarge Bags'])
df['year'] = np.sqrt(df['year'])

df.skew()
# Out:
# Unnamed: 0     -0.234824
# AveragePrice   -0.109444
# Total Volume    3.129360
# 4046            2.883385
# 4225            2.891611
# 4770            2.531303
# Total Bags      2.951677
# Small Bags      2.956167
# Large Bags      2.517165
# XLarge Bags     2.916661
# type            0.000000
# year            1.828332
# region          0.288146
# Day             0.041303
# Month           0.101439
# Year            1.828332
# dtype: float64

# %% [raw]
# again we have to do.

# %%
df['Total Volume'] = np.sqrt(df['Total Volume'])
df['4046'] = np.sqrt(df['4046'])
df['4225'] = np.sqrt(df['4225'])
df['4770'] = np.sqrt(df['4770'])
df['Total Bags'] = np.sqrt(df['Total Bags'])
df['Small Bags'] = np.sqrt(df['Small Bags'])
df['Large Bags'] = np.sqrt(df['Large Bags'])
df['XLarge Bags'] = np.sqrt(df['XLarge Bags'])
df['year'] = np.sqrt(df['year'])

df.skew()
# Out:
# Unnamed: 0     -0.234824
# AveragePrice   -0.109444
# Total Volume    1.691618
# 4046            1.244574
# 4225            1.312120
# 4770            1.031282
# Total Bags      1.768733
# Small Bags      1.760192
# Large Bags      0.809769
# XLarge Bags     1.475524
# type            0.000000
# year            1.828332
# region          0.288146
# Day             0.041303
# Month           0.101439
# Year            1.828332
# dtype: float64

# %% [raw]
# One more time we have to do

# %%
df['Total Volume'] = np.sqrt(df['Total Volume'])
df['4046'] = np.sqrt(df['4046'])
df['4225'] = np.sqrt(df['4225'])
df['4770'] = np.sqrt(df['4770'])
df['Total Bags'] = np.sqrt(df['Total Bags'])
df['Small Bags'] = np.sqrt(df['Small Bags'])
df['Large Bags'] = np.sqrt(df['Large Bags'])
df['XLarge Bags'] = np.sqrt(df['XLarge Bags'])
df['year'] = np.sqrt(df['year'])

df.skew()
# Out:
# Unnamed: 0     -0.234824
# AveragePrice   -0.109444
# Total Volume    1.133204
# 4046            0.507881
# 4225            0.715780
# 4770            0.296215
# Total Bags      1.221790
# Small Bags      1.218239
# Large Bags     -0.599991
# XLarge Bags     0.615139
# type            0.000000
# year            1.828332
# region          0.288146
# Day             0.041303
# Month           0.101439
# Year            1.828332
# dtype: float64

# %%
df['Total Volume'] = np.sqrt(df['Total Volume'])
df['Total Bags'] = np.sqrt(df['Total Bags'])
df['Small Bags'] = np.sqrt(df['Small Bags'])

df.skew()
# Out:
# Unnamed: 0     -0.234824
# AveragePrice   -0.109444
# Total Volume    0.890082
# 4046            0.507881
# 4225            0.715780
# 4770            0.296215
# Total Bags      0.956575
# Small Bags      0.961554
# Large Bags     -0.599991
# XLarge Bags     0.615139
# type            0.000000
# year            1.828332
# region          0.288146
# Day             0.041303
# Month           0.101439
# Year            1.828332
# dtype: float64

# %%
df.corr()
# Out:
#               Unnamed: 0  AveragePrice  Total Volume      4046      4225  \
# Unnamed: 0      1.000000     -0.075531      0.100558  0.111147  0.055364
# AveragePrice   -0.075531      1.000000     -0.320639 -0.506639 -0.136206
# Total Volume    0.100558     -0.320639      1.000000  0.820262  0.916732
# 4046            0.111147     -0.506639      0.820262  1.000000  0.569227
# 4225            0.055364     -0.136206      0.916732  0.569227  1.000000
# 4770            0.023600     -0.258146      0.700959  0.632429  0.641836
# Total Bags      0.086892     -0.186845      0.943629  0.717055  0.879165
# Small Bags      0.095185     -0.147372      0.930461  0.683943  0.885415
# Large Bags      0.063975     -0.234034      0.642264  0.587830  0.531805
# XLarge Bags    -0.104249     -0.073790      0.444841  0.369786  0.414396
# type                 NaN           NaN           NaN       NaN       NaN
# year           -0.012854      0.178683      0.007142 -0.109024  0.023062
# ...

# %%
df['type'].replace('',np.nan,inplace=True)
df.dropna(subset=['type'], inplace=True)

# %%
df.corr()
# Out:
#               Unnamed: 0  AveragePrice  Total Volume      4046      4225  \
# Unnamed: 0      1.000000     -0.075531      0.100558  0.111147  0.055364
# AveragePrice   -0.075531      1.000000     -0.320639 -0.506639 -0.136206
# Total Volume    0.100558     -0.320639      1.000000  0.820262  0.916732
# 4046            0.111147     -0.506639      0.820262  1.000000  0.569227
# 4225            0.055364     -0.136206      0.916732  0.569227  1.000000
# 4770            0.023600     -0.258146      0.700959  0.632429  0.641836
# Total Bags      0.086892     -0.186845      0.943629  0.717055  0.879165
# Small Bags      0.095185     -0.147372      0.930461  0.683943  0.885415
# Large Bags      0.063975     -0.234034      0.642264  0.587830  0.531805
# XLarge Bags    -0.104249     -0.073790      0.444841  0.369786  0.414396
# type                 NaN           NaN           NaN       NaN       NaN
# year           -0.012854      0.178683      0.007142 -0.109024  0.023062
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,linewidths=0.5,linecolor="black",fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Outcome of Correlation

# %% [raw]
# All the columns are not positively connected to target column.
#
# Total Volume has less 32 percent correlation with the target column which can be considered as a weak bond.
# 4046 has less 51 percent correlation with the target column which can be considered as a weak bond.
# 4225 has less 14 percent correlation with the target column which can be considered as a weak bond.
# 4770 has less 26 percent correlation with the target column which can be considered as a weak bond.
# Total Bags has less 19 percent correlation with the target column which can be considered as a weak bond.
# Small Bags has less 15 percent correlation with the target column which can be considered as a weak bond.
# Large Bags has less 23 percent correlation with the target column which can be considered as a weak bgood bond.
# XLarge Bags has less 7 percent correlation with the target column which can be considered as a weak bond.
# Day has 9 percent correlation with the target column which can be considered as a good bond.
# Month has 6 percent correlation with the target column which can be considered as a good bond.
# Year has 18 percent correlation with the target column which can be considered as a good bond.
#
#
# Max Correlation : AveragePrice
#
# Min Correlation : 4046

# %%
df.corr()
# Out:
#               Unnamed: 0  AveragePrice  Total Volume      4046      4225  \
# Unnamed: 0      1.000000     -0.075531      0.100558  0.111147  0.055364
# AveragePrice   -0.075531      1.000000     -0.320639 -0.506639 -0.136206
# Total Volume    0.100558     -0.320639      1.000000  0.820262  0.916732
# 4046            0.111147     -0.506639      0.820262  1.000000  0.569227
# 4225            0.055364     -0.136206      0.916732  0.569227  1.000000
# 4770            0.023600     -0.258146      0.700959  0.632429  0.641836
# Total Bags      0.086892     -0.186845      0.943629  0.717055  0.879165
# Small Bags      0.095185     -0.147372      0.930461  0.683943  0.885415
# Large Bags      0.063975     -0.234034      0.642264  0.587830  0.531805
# XLarge Bags    -0.104249     -0.073790      0.444841  0.369786  0.414396
# type                 NaN           NaN           NaN       NaN       NaN
# year           -0.012854      0.178683      0.007142 -0.109024  0.023062
# ...

# %% [markdown]
# # Dividing the Data into x and y

# %%
x = df.iloc[:,-14:]

x
# Out:
#       Total Volume      4046      4225      4770  Total Bags  Small Bags  \
# 0         1.997498  2.382093  3.908450  1.623065    1.762829    1.761642
# 1         1.977934  2.257382  3.812537  1.662404    1.772652    1.771511
# 2         2.075120  2.304228  4.263368  1.838448    1.755625    1.754228
# 3         2.023480  2.408412  4.047145  1.708449    1.718963    1.716463
# 4         1.968993  2.353566  3.803924  1.717688    1.725656    1.722155
# ...            ...       ...       ...       ...         ...         ...
# 1512      2.138172  3.935374  3.925345  3.392175    1.987788    1.963538
# 1513      2.129056  3.798336  3.887747  3.435816    1.995667    1.977544
# 1514      2.129187  3.830659  3.894262  3.372558    1.993912    1.974409
# 1515      2.136967  3.905355  3.900669  3.391295    1.996904    1.979672
# 1516      2.132554  3.796036  3.906100  3.368181    2.006639    1.983620
#
#       Large Bags  XLarge Bags  type      year  region   Day  Month    Year
# ...

# %%
x.shape
# Out:
# (1517, 14)

# %%
y = df.iloc[:,-14]
y
# Out:
# 0       1.997498
# 1       1.977934
# 2       2.075120
# 3       2.023480
# 4       1.968993
#           ...
# 1512    2.138172
# 1513    2.129056
# 1514    2.129187
# 1515    2.136967
# 1516    2.132554
# Name: Total Volume, Length: 1517, dtype: float64

# %%
y.shape
# Out:
# (1517,)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB

from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import warnings
warnings.filterwarnings('ignore')

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=.22,random_state=42)

# %%
dtc = DecisionTreeClassifier()
dtc.fit(xtrain,ytrain)
dtc.score(xtrain,ytrain)
preddtc = dtc.predict(xtest)
print(accuracy_score(ytest,preddtc))
print(confusion_matrix(ytest,preddtc))
print(classification_report(ytest,preddtc))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-12875c9f7299> in <module>
#       1 dtc = DecisionTreeClassifier()
# ----> 2 dtc.fit(xtrain,ytrain)
#       3 dtc.score(xtrain,ytrain)
#       4 preddtc = dtc.predict(xtest)
#       5 print(accuracy_score(ytest,preddtc))
#
# F:\Namrata\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     901         """
#     902
# --> 903         super().fit(
#     904             X, y,
#     905             sample_weight=sample_weight,
#
# F:\Namrata\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     189
#     190         if is_classification:
# --> 191             check_classification_targets(y)
#     192             y = np.copy(y)
#     193
#
# ...

# %%
mnb=MultinomialNB()
mnb.fit(xtrain,ytrain)
predmnb=mnb.predict(xtest)
print(accuracy_score(ytest,predmnb))
print(confusion_matrix(ytest,predmnb))
print(classification_report(ytest,predmnb))

# %%
svc=SVC(kernel='rbf')  
svc.fit(xtrain,ytrain)
svc.score(xtrain,ytrain)
predsvc=svc.predict(xtest)
print(accuracy_score(ytest,predsvc))
print(confusion_matrix(ytest,predsvc))
print(classification_report(ytest,predsvc))

# %%
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(xtrain,ytrain)
knn.score(xtrain,ytrain)
predknn=knn.predict(xtest)
print(accuracy_score(ytest,predknn))
print(confusion_matrix(ytest,predknn))
print(classification_report(ytest,predknn))

# %%
svc=SVC(kernel='poly')   
svc.fit(xtrain,ytrain)
svc.score(xtrain,ytrain)
predsvc=svc.predict(xtest)
print(accuracy_score(ytest,predsvc))
print(confusion_matrix(ytest,predsvc))
print(classification_report(ytest,predsvc))

# %% [markdown]
# # Saving the best model

# %%
import pickle

filename = 'pickledtcfile3.pkl'
pickle.dump(dtc,open(filename,'wb'))

# load the model from disk

loaded_model = pickle.load(open(filename,'rb'))
loaded_model.predict(xtest)
